# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('DiD_data.csv')
df2 = df.dropna()
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#        rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0       1020180  20040930                  0.0              0            0
# 1       1020180  20041231                  0.0              0            0
# 2       1020180  20050331                  0.0              0            0
# 3       1020180  20050630                  0.0              0            0
# 4       1020180  20050930                  0.0              0            0
# ...         ...       ...                  ...            ...          ...
# 40021   3832583  20140331                  0.0              0            1
# 40022   3832583  20140630                  0.0              0            1
# 40023   3832583  20140930                  0.0              0            1
# 40024   3832583  20141231                  0.0              0            1
# 40025   3836442  20090630                  0.0              0            0
#
# ...

# %% [markdown]
# # Panel B Test 1

# %%
PanelB_1 = smf.ols(formula='bhc_avgtradingratio ~ after_DFA_1*treat_3_b_avg + C(rssd9001) + C(rssd9999) + dep_roa1', data=df2).fit()
print(PanelB_1.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     bhc_avgtradingratio   R-squared:                       0.922
# Model:                             OLS   Adj. R-squared:                  0.917
# Method:                  Least Squares   F-statistic:                     181.2
# Date:                 Sun, 07 Nov 2021   Prob (F-statistic):               0.00
# Time:                         19:18:26   Log-Likelihood:             1.5179e+05
# No. Observations:                40026   AIC:                        -2.986e+05
# Df Residuals:                    37559   BIC:                        -2.774e+05
# Df Model:                         2466
# Covariance Type:             nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.0007      0.001     -0.718      0.473      -0.003       0.001
# ...

# %% [markdown]
# #PANEL B Test 2

# %%
df_matched_all = pd.read_csv('C:\\Users\crist\OneDrive\Desktop\Jupyter\Excel files\matched_df_all.csv')
df_matched_all = df_matched_all.drop('Unnamed: 0', axis=1)
df_matched_all
# Out:
#       rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0      1020201  20040930             0.126453              1            0
# 1      1020201  20041231             0.139026              1            0
# 2      1020201  20050331             0.130043              1            0
# 3      1020201  20050630             0.131771              1            0
# 4      1020201  20050930             0.135333              1            0
# ...        ...       ...                  ...            ...          ...
# 1752   2043319  20041231             0.000000              0            0
# 1753   2043319  20050331             0.000000              0            0
# 1754   2043319  20050630             0.000000              0            0
# 1755   2043319  20050930             0.000000              0            0
# 1756   2043319  20051231             0.000000              0            0
#
#       dep_roa1  dep_leverage  dep_lnassets  dep_creditrisk_total3   dep_cir  \
# ...

# %%
PanelB_2 = smf.ols(formula='bhc_avgtradingratio ~ after_DFA_1*treat_3_b_avg + C(rssd9001) + C(rssd9999) + dep_roa1 + dep_leverage + dep_lnassets + dep_creditrisk_total3 + dep_cir + dep_depositratio + dep_loans_REratio + dep_liquidity + dep_cpp_bankquarter', data=df_matched_all).fit()
print(PanelB_2.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     bhc_avgtradingratio   R-squared:                       0.926
# Model:                             OLS   Adj. R-squared:                  0.923
# Method:                  Least Squares   F-statistic:                     244.7
# Date:                 Sun, 07 Nov 2021   Prob (F-statistic):               0.00
# Time:                         18:10:56   Log-Likelihood:                 4953.9
# No. Observations:                 1757   AIC:                            -9734.
# Df Residuals:                     1670   BIC:                            -9258.
# Df Model:                           86
# Covariance Type:             nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.2390      0.055      4.350      0.000       0.131       0.347
# ...

# %% [markdown]
# # Panel B Test 3

# %%
df_pre2007_affect = pd.read_csv('C:\\Users\crist\OneDrive\Desktop\Jupyter\Excel files\df_pre07_BHC_Affect_var.csv')
df_pre2007_affect=df_pre2007_affect.rename(columns = {'Affect':'Affect_Pre_2007'})
df_pre2007_affect
# Out:
#       rssd9001  Affect_Pre_2007
# 0      1056769              0.0
# 1      3219474              0.0
# 2      1916948              0.0
# 3      2482196              0.0
# 4      2236447              0.0
# ...        ...              ...
# 2428   2858979              0.0
# 2429   2670573              0.0
# 2430   1417203              0.0
# 2431   2170868              0.0
# 2432   2637820              0.0
#
# [2433 rows x 2 columns]

# %%
df_panelb_3 = df2.merge(df_pre2007_affect, how='left', on='rssd9001')
df_panelb_3
# Out:
#        rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0       1020180  20040930                  0.0              0            0
# 1       1020180  20041231                  0.0              0            0
# 2       1020180  20050331                  0.0              0            0
# 3       1020180  20050630                  0.0              0            0
# 4       1020180  20050930                  0.0              0            0
# ...         ...       ...                  ...            ...          ...
# 40021   3832583  20140331                  0.0              0            1
# 40022   3832583  20140630                  0.0              0            1
# 40023   3832583  20140930                  0.0              0            1
# 40024   3832583  20141231                  0.0              0            1
# 40025   3836442  20090630                  0.0              0            0
#
# ...

# %%
df_panelb_3.dropna(inplace=True)
df_panelb_3
# Out:
#        rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0       1020180  20040930                  0.0              0            0
# 1       1020180  20041231                  0.0              0            0
# 2       1020180  20050331                  0.0              0            0
# 3       1020180  20050630                  0.0              0            0
# 4       1020180  20050930                  0.0              0            0
# ...         ...       ...                  ...            ...          ...
# 39292   3444847  20141231                  0.0              0            1
# 39293   3445424  20061231                  0.0              0            0
# 39294   3445424  20070331                  0.0              0            0
# 39295   3445424  20070630                  0.0              0            0
# 39296   3445424  20070930                  0.0              0            0
#
# ...

# %%
PanelB_3 = smf.ols(formula='bhc_avgtradingratio ~ after_DFA_1*Affect_Pre_2007 + C(rssd9001) + C(rssd9999) + dep_roa1 + dep_leverage + dep_lnassets + dep_creditrisk_total3 + dep_cir + dep_depositratio + dep_loans_REratio + dep_liquidity + dep_cpp_bankquarter', data=df_panelb_3).fit()
print(PanelB_3.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     bhc_avgtradingratio   R-squared:                       0.894
# Model:                             OLS   Adj. R-squared:                  0.887
# Method:                  Least Squares   F-statistic:                     127.5
# Date:                 Sun, 07 Nov 2021   Prob (F-statistic):               0.00
# Time:                         18:14:52   Log-Likelihood:             1.4860e+05
# No. Observations:                38783   AIC:                        -2.924e+05
# Df Residuals:                    36378   BIC:                        -2.718e+05
# Df Model:                         2404
# Covariance Type:             nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Panel B Test 4

# %%
df_nonzero_bhc = pd.read_csv('C:\\Users\crist\OneDrive\Desktop\Jupyter\Excel files\df_nonzero_tradingratio.csv')
df_nonzero_bhc
# Out:
#       rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0      1020201  20040930             0.126453              1            0
# 1      1020201  20041231             0.139026              1            0
# 2      1020201  20050331             0.130043              1            0
# 3      1020201  20050630             0.131771              1            0
# 4      1020201  20050930             0.135333              1            0
# ...        ...       ...                  ...            ...          ...
# 4771   3762457  20131231             0.000327              0            1
# 4772   3762457  20140331             0.000336              0            1
# 4773   3762457  20140630             0.000267              0            1
# 4774   3762457  20140930             0.000276              0            1
# 4775   3762457  20141231             0.000300              0            1
#
#       dep_roa1  dep_leverage  dep_lnassets  dep_creditrisk_total3   dep_cir  \
# ...

# %%
df_nonzerobhc_affect = df_nonzero_bhc.merge(df_pre2007_affect, how='left', on='rssd9001')
df_nonzerobhc_affect.dropna(inplace=True)
df_nonzerobhc_affect
# Out:
#       rssd9001  rssd9999  bhc_avgtradingratio  treat_3_b_avg  after_DFA_1  \
# 0      1020201  20040930             0.126453              1            0
# 1      1020201  20041231             0.139026              1            0
# 2      1020201  20050331             0.130043              1            0
# 3      1020201  20050630             0.131771              1            0
# 4      1020201  20050930             0.135333              1            0
# ...        ...       ...                  ...            ...          ...
# 4603   3242838  20140930             0.003877              0            1
# 4604   3242838  20141231             0.003431              0            1
# 4605   3305461  20050630             0.000045              0            0
# 4606   3305461  20050930             0.000046              0            0
# 4607   3305461  20051231             0.000045              0            0
#
#       dep_roa1  dep_leverage  dep_lnassets  dep_creditrisk_total3   dep_cir  \
# ...

# %%
PanelB_4 = smf.ols(formula='bhc_avgtradingratio ~ after_DFA_1*Affect_Pre_2007 + C(rssd9001) + C(rssd9999) + dep_roa1 + dep_leverage + dep_lnassets + dep_creditrisk_total3 + dep_cir + dep_depositratio + dep_loans_REratio + dep_liquidity + dep_cpp_bankquarter', data=df_nonzerobhc_affect).fit()
print(PanelB_4.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     bhc_avgtradingratio   R-squared:                       0.911
# Model:                             OLS   Adj. R-squared:                  0.903
# Method:                  Least Squares   F-statistic:                     118.6
# Date:                 Sun, 07 Nov 2021   Prob (F-statistic):               0.00
# Time:                         18:14:54   Log-Likelihood:                 13068.
# No. Observations:                 4493   AIC:                        -2.542e+04
# Df Residuals:                     4136   BIC:                        -2.313e+04
# Df Model:                          356
# Covariance Type:             nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...
